# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariajoseduran/PROGCOM-A/blob/main/Clase10_POO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROGRAMACIÓN ORIENTADA A OBJETOS
# 1. Es un paradigma de programación (no orientado al procedimiento).
# 2. Tiene 4 pilares fundamentales:
# Herencia, polimorfismo, abstracción, encapsulamiento.
# 3. Ventajas
# * Modularidad: Manejar el código por trozos.
# * Reusabilidad: Reusar clases y objetos.
# * Mantenimiento: Agregar fácilmente nuevos métodos.
# * Escalabilidad: Escalar a nuevas aplicaciones desde un mismo código.
# * Seguridad: No todos pueden alterar el código.
# 4. A los molde, croquis --> clases
# 5. Lo que produce una clase --> Instancia de clase --> Objetos
# 6. Funciones --> Método
# 7. Variables --> Atributos
# 8. sintaxis
#
#
#
# ```
# class NombreClase(atributos):
#   #Constructor
#   def __init__(self,p1,p2,p3,...pn):
#     pass
#   def metodo1():
#     pass
#   def metodo2():
#     pass
# ```
#
# 9. Invocando una clase
#
#
# ```
# variable=NombreClase()
# ```

# %%
class disfraz():
  #creando al constructor
  def __init__(self,color,talla,forma,material,personaje):
    #creando atributos de clase
    self.color=color
    self.talla=talla
    self.forma=forma
    self.material=material
    self.personaje=personaje

  def imprimir(self):
    return f"eldisfraz es de {self.personaje}.\nEs de talla {self.talla}.\nEs de color {self.color}.\nEs de forma {self.forma}.\nEs de material {self.material}."

# %%
perro=disfraz("amarillo con marron","10","cuadrado","tela","bob esponja")

# %%
perro.imprimir()
# Out:
# 'eldisfraz es de bob esponja.\nEs de talla 10.\nEs de color amarillo con marron.\nEs de forma cuadrado.\nEs de material tela.'

# %%
print(perro.imprimir())
# Out:
# eldisfraz es de bob esponja.
# Es de talla 10.
# Es de color amarillo con marron.
# Es de forma cuadrado.
# Es de material tela.

# %%
class Edificio():
  #construyendo el constructor
  def __init__(self,material,ubicacion,fachada,ventanas,puertas,nombre):
    self.material=material
    self.ubicacion=ubicacion
    self.fachada=fachada
    self.ventanas=ventanas
    self.puertas=puertas
    self.nombre=nombre
    def direccion(self):
      return f"Tipo de direccion:{tipo}\nDireccion: {self.ubicacion}."

  def descripcion(self,tipo):
      print(f"{self.nombre} es un {tipo} ubicado en {self.ubicacion}")
      print(f"tiene {self.ventanas} ventana (s), {self.puertas} puerta(s)")
      print(f"su fachada es {self.fachada}")

# %%
Colegio=Edificio("ladrillo","Bucaramanga","De colores pasteles",4,2,"los angelitos")
Floristeria=Edificio("Ladrillo","floridablanca","campestre con ceped verde",0,2,"florecita")

# %%
Colegio.descripcion("Colegio")
# Out:
# los angelitos es un Colegio ubicado en Bucaramanga
# tiene 4 ventana (s), 2 puerta(s)
# su fachada es De colores pasteles

# %%
colegio.fachada="colores pasteles, con cesped verde y angelitos"

# %%
# ── DESCRIPCIÓN DE LUGARES ────────────────────────────────

def pedir(msg, num=False):
    while True:
        v = input(f"  {msg}: ").strip()
        if not v:
            print("  ⚠ Campo obligatorio.")
            continue
        if num:
            try: return int(v)
            except: print("  ⚠ Ingresa un número."); continue
        return v

def pedir_lista(msg):
    print(f"\n  {msg} (deja en blanco para terminar)")
    items, i = [], 1
    while True:
        v = input(f"    [{i}] ").strip()
        if not v and items: break
        if not v: print("  ⚠ Mínimo uno."); continue
        items.append(v); i += 1
    return items

def registrar():
    print("\n" + "="*50)
    d = {}
    d["nombre"]      = pedir("Nombre del lugar")
    d["tipo"]        = pedir("Tipo de lugar (floristería, colegio, etc.)")
    d["descripcion"] = pedir("Descripción general")
    d["capacidad"]   = pedir("Capacidad o número de personas", num=True)
    d["espacios"]    = pedir("Número de espacios o ambientes", num=True)
    d["horario"]     = pedir("Horario (ej: Lun-Vie 8am-6pm)")
    d["servicios"]   = pedir_lista("Servicios o características")
    return d

def mostrar(d):
    print("\n" + "="*50)
    print(f"  {d['nombre'].upper()}  ({d['tipo']})")
    print("="*50)
    print(f"\n  {d['descripcion']}")
    print(f"\n  Capacidad : {d['capacidad']}")
    print(f"  Espacios  : {d['espacios']}")
    print(f"  Horario   : {d['horario']}")
    print(f"\n  Servicios:")
    for i, s in enumerate(d["servicios"], 1):
        print(f"    {i}. {s}")
    print("="*50)

# ── Ejecutar ───────────────────────────────────────────────
lugar = registrar()
mostrar(lugar)
# Out:
# ...
#   Nombre del lugar: EL FLORISTA
#   Tipo de lugar (floristería, colegio, etc.): Floristería
#   Descripción general: es una floristería con un encanto rústico y bohemio que destaca por su fachada de color amarillo cálido y marcos oscuros. La tienda desborda vida hacia la acera empedrada a través de una densa colección de plantas dispuestas en cestas de mimbre, cajas de madera y macetas de diversos tamaños, donde resaltan flores rojas, amarillas y variados arbustos verdes. En la entrada, múltiples macetas colgantes añaden una capa vertical de follaje que enmarca el gran ventanal, a través del cual se observa a los floristas trabajando en un interior iluminado y lleno de vegetación. El ambiente, capturado al atardecer o bajo luz artificial suave, evoca la tranquilidad de una calle europea, con una mujer caminando frente al local que acentúa la escala humana y el aire cotidiano de este rincón botánico urbano.
#   Capacidad o número de personas: 5
#   Número de espacios o ambientes: 1
# ...

# %% [markdown]
# **POO** (Programación Orientada a Objetos) --> Creo la base pero se decora diferente
